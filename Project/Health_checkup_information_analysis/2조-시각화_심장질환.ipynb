# %% [markdown]
# # 심장질환에 따른 질병여부 비교

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

plt.rcParams['font.family'] = 'Malgun Gothic'
plt.rcParams['axes.unicode_minus'] = False

# %%
심장질환 = pd.read_csv(
    "./심장질환.csv",
)

# %%
심장질환
# Out:
#         기준년도  가입자 일련번호       시도 성별  연령대  신장(5Cm단위)  체중(5Kg 단위)  허리둘레  시력(좌)  \
# 0       2020         1  세종특별자치시  남  40대        165          60  72.1    1.2
# 1       2020         5      경기도  여  50대        155          50  75.2    1.5
# 2       2020         6    대구광역시  남  40대        185          85  94.0    1.2
# 3       2020         7     충청남도  남  40대        165          80  93.0    0.8
# 4       2020         9      경기도  여  80대        150          50  82.0    0.4
# ...      ...       ...      ... ..  ...        ...         ...   ...    ...
# 394452  2020    999993    대전광역시  남  60대        175          90  99.5    0.9
# 394453  2020    999996      경기도  여  60대        145          55  81.0    0.9
# 394454  2020    999997    부산광역시  여  50대        160          55  76.5    1.5
# 394455  2020    999999     경상남도  여  40대        160          70  91.0    0.6
# 394456  2020   1000000    인천광역시  남  50대        160          55  76.1    2.0
#
#         시력(우)  ...    데이터 공개일자  빈혈유무        BMI    비만정도    혈압      당뇨  \
# 0         1.5  ...  2021-12-29    정상  22.038567      정상  정상혈압      정상
# 1         1.2  ...  2021-12-29    정상  20.811655      정상   고혈압  공복혈당장애
# 2         1.2  ...  2021-12-29    정상  24.835646    위험체중  정상혈압      정상
# 3         0.7  ...  2021-12-29    정상  29.384757  1단계 비만  정상혈압     당뇨병
# 4         0.5  ...  2021-12-29    정상  22.222222      정상  정상혈압  공복혈당장애
# ...       ...  ...         ...   ...        ...     ...   ...     ...
# 394452    0.9  ...  2021-12-29    정상  29.387755  1단계 비만  정상혈압      정상
# 394453    1.0  ...  2021-12-29    정상  26.159334  1단계 비만  정상혈압  공복혈당장애
# 394454    1.5  ...  2021-12-29    정상  21.484375      정상  정상혈압      정상
# 394455    0.5  ...  2021-12-29   비정상  27.343750  1단계 비만  정상혈압  공복혈당장애
# 394456    2.0  ...  2021-12-29    정상  21.484375      정상  정상혈압  공복혈당장애
#
#         혈청크레아티닌유무  신장질환  간질환      심장질환
# 0              정상    정상   정상        정상
# 1              정상    정상   정상  LDL,트리글리
# 2              정상    정상   정상  LDL,트리글리
# 3              정상    정상   정상  HDL,트리글리
# 4              정상    정상  비정상        정상
# ...           ...   ...  ...       ...
# 394452         정상    정상  비정상       HDL
# 394453         정상    정상   정상      트리글리
# 394454         정상    정상   정상       LDL
# 394455         정상    정상   정상        정상
# 394456         정상    정상   정상       LDL
#
# [394457 rows x 40 columns]
