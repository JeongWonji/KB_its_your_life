# %%
import pandas as pd
import numpy as np

apt_price = pd.read_csv(
    "./data/apt_price_2022.csv",
    encoding="cp949", #한글전용코드 지정
    skiprows=15, #15줄은 설명문
    thousands="," # 3자리구분코드 ","를 없애기
)
# UnicodeDecodeError : 유니코드파일이 아니라서 오류
# ParserError : csv형식이 일정치 않음

# %%
apt_price
# Out:
#                  시군구      번지     본번    부번             단지명  전용면적(㎡)    계약년월  \
# 0      서울특별시 강남구 개포동   658-1  658.0   1.0  개포6차우성아파트1동~8동    79.97  202109
# 1      서울특별시 강남구 개포동   658-1  658.0   1.0  개포6차우성아파트1동~8동    79.97  202112
# 2      서울특별시 강남구 개포동   658-1  658.0   1.0  개포6차우성아파트1동~8동    79.97  202204
# 3      서울특별시 강남구 개포동   658-1  658.0   1.0  개포6차우성아파트1동~8동    79.97  202204
# 4      서울특별시 강남구 개포동   658-1  658.0   1.0  개포6차우성아파트1동~8동    79.97  202205
# ...              ...     ...    ...   ...             ...      ...     ...
# 16942  서울특별시 중랑구 중화동     450  450.0   0.0  한신아파트(103~109)    59.76  202207
# 16943  서울특별시 중랑구 중화동     450  450.0   0.0  한신아파트(103~109)    84.03  202207
# 16944  서울특별시 중랑구 중화동  274-51  274.0  51.0         한영(101)    84.69  202111
# 16945  서울특별시 중랑구 중화동  274-51  274.0  51.0         한영(101)    84.69  202204
# 16946  서울특별시 중랑구 중화동    11-7   11.0   7.0     현대휴앤미(102동)    76.43  202204
#
# ...

# %%
type(apt_price)
# Out:
# pandas.core.frame.DataFrame

# %%
type(apt_price)
# Out:
# pandas.core.frame.DataFrame

# %%
apt_price.columns #열 이름
# Out:
# Index(['시군구', '번지', '본번', '부번', '단지명', '전용면적(㎡)', '계약년월', '계약일', '거래금액(만원)',
#        '층', '건축년도', '도로명', '해제사유발생일', '거래유형', '중개사소재지'],
#       dtype='object')

# %%
 apt_price.index # 행 번호
# Out:
# RangeIndex(start=0, stop=16947, step=1)

# %%
apt_price.values # 데이터 - 2d numpy
# Out:
# array([['서울특별시 강남구 개포동', '658-1', 658.0, ..., nan, '-', '-'],
#        ['서울특별시 강남구 개포동', '658-1', 658.0, ..., nan, '중개거래', '서울 강남구'],
#        ['서울특별시 강남구 개포동', '658-1', 658.0, ..., nan, '중개거래', '서울 강남구'],
#        ...,
#        ['서울특별시 중랑구 중화동', '274-51', 274.0, ..., nan, '중개거래',
#         '서울 송파구, 서울 중랑구'],
#        ['서울특별시 중랑구 중화동', '274-51', 274.0, ..., nan, '중개거래', '서울 중랑구'],
#        ['서울특별시 중랑구 중화동', '11-7', 11.0, ..., nan, '중개거래', '서울 중랑구']],
#       dtype=object)

# %%
type(apt_price.values)
# Out:
# numpy.ndarray

# %%
apt_price.values.shape
# Out:
# (16947, 15)

# %%
apt_price.size
# Out:
# 254205

# %%
apt_price.values[0] #pd로 읽어올때 앞에서 thousands 옵션 안줬을 때 결과값
# Out:
# array(['서울특별시 강남구 개포동', '658-1', 658.0, 1.0, '개포6차우성아파트1동~8동', 79.97,
#        202109, 2, '220,000', 2, 1987.0, '언주로 3', nan, '-', '-'],
#       dtype=object)

# %%
apt_price.values[0] # thousands 옵션 줬을 떄 결과값
# Out:
# array(['서울특별시 강남구 개포동', '658-1', 658.0, 1.0, '개포6차우성아파트1동~8동', 79.97,
#        202109, 2, 220000, 2, 1987.0, '언주로 3', nan, '-', '-'], dtype=object)

# %%
apt_price.values[-1]
# Out:
# array(['서울특별시 중랑구 중화동', '11-7', 11.0, 7.0, '현대휴앤미(102동)', 76.43, 202204,
#        23, 53000, 6, 2007.0, '봉화산로27가길 19', nan, '중개거래', '서울 중랑구'],
#       dtype=object)

# %%
type(apt_price.values[0])
# Out:
# numpy.ndarray

# %%
type(apt_price["시군구"])
# Out:
# pandas.core.series.Series

# %%
apt_price["시군구"][-1]
#리스트 아니고 시리즈라서 안돼~~! 
# list의 index와 다르게 -1 이런식으로 접근 노노~
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\range.py:385, in RangeIndex.get_loc(self, key, method, tolerance)
#     384 try:
# --> 385     return self._range.index(new_key)
#     386 except ValueError as err:
#
# ValueError: -1 is not in range
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Input In [3], in <cell line: 1>()
# ----> 1 apt_price["시군구"][-1]
#
# File ~\anaconda3\lib\site-packages\pandas\core\series.py:958, in Series.__getitem__(self, key)
#     955     return self._values[key]
#     957 elif key_is_scalar:
# --> 958     return self._get_value(key)
#     960 if is_hashable(key):
#     961     # Otherwise index.get_value will raise InvalidIndexError
#     962     try:
# ...

# %%
apt_price["시군구"][0] #이건 가능~
# Out:
# '서울특별시 강남구 개포동'

# %%
# apt_price["단지명"] #아파트이름
money = apt_price["거래금액(만원)"]
money.index = apt_price["단지명"]
money
# Out:
# 단지명
# 개포6차우성아파트1동~8동    220000
# 개포6차우성아파트1동~8동    215000
# 개포6차우성아파트1동~8동    220000
# 개포6차우성아파트1동~8동    220000
# 개포6차우성아파트1동~8동    216000
#                    ...
# 한신아파트(103~109)     74000
# 한신아파트(103~109)     91500
# 한영(101)            50000
# 한영(101)            49900
# 현대휴앤미(102동)        53000
# Name: 거래금액(만원), Length: 16947, dtype: int64

# %%
apt_price["해제사유발생일"][
    apt_price["해제사유발생일"].notna()
]
# Out:
# 96       20220111.0
# 100      20220320.0
# 116      20211231.0
# 136      20220818.0
# 141      20211007.0
#             ...
# 16788    20211111.0
# 16795    20220125.0
# 16847    20211206.0
# 16895    20211228.0
# 16931    20220607.0
# Name: 해제사유발생일, Length: 665, dtype: float64

# %%
apt_price.columns
# Out:
# Index(['시군구', '번지', '본번', '부번', '단지명', '전용면적(㎡)', '계약년월', '계약일', '거래금액(만원)',
#        '층', '건축년도', '도로명', '해제사유발생일', '거래유형', '중개사소재지'],
#       dtype='object')

# %%
for c in list(apt_price.columns):
    print(c)
# Out:
# 시군구
# 번지
# 본번
# 부번
# 단지명
# 전용면적(㎡)
# 계약년월
# 계약일
# 거래금액(만원)
# 층
# 건축년도
# 도로명
# 해제사유발생일
# 거래유형
# 중개사소재지

# %%
type(apt_price.columns)
# Out:
# pandas.core.indexes.base.Index

# %%
apt_price.T
# Out:
#                    0               1               2               3      \
# 시군구        서울특별시 강남구 개포동   서울특별시 강남구 개포동   서울특별시 강남구 개포동   서울특별시 강남구 개포동
# 번지                 658-1           658-1           658-1           658-1
# 본번                 658.0           658.0           658.0           658.0
# 부번                   1.0             1.0             1.0             1.0
# 단지명       개포6차우성아파트1동~8동  개포6차우성아파트1동~8동  개포6차우성아파트1동~8동  개포6차우성아파트1동~8동
# 전용면적(㎡)            79.97           79.97           79.97           79.97
# 계약년월              202109          202112          202204          202204
# 계약일                    2               4              12              21
# 거래금액(만원)          220000          215000          220000          220000
# 층                      2               3               4               2
# 건축년도              1987.0          1987.0          1987.0          1987.0
# 도로명                언주로 3           언주로 3           언주로 3           언주로 3
# ...

# %%
display(apt_price[["시군구", "단지명"]])
# Out:
#                  시군구             단지명
# 0      서울특별시 강남구 개포동  개포6차우성아파트1동~8동
# 1      서울특별시 강남구 개포동  개포6차우성아파트1동~8동
# 2      서울특별시 강남구 개포동  개포6차우성아파트1동~8동
# 3      서울특별시 강남구 개포동  개포6차우성아파트1동~8동
# 4      서울특별시 강남구 개포동  개포6차우성아파트1동~8동
# ...              ...             ...
# 16942  서울특별시 중랑구 중화동  한신아파트(103~109)
# 16943  서울특별시 중랑구 중화동  한신아파트(103~109)
# 16944  서울특별시 중랑구 중화동         한영(101)
# 16945  서울특별시 중랑구 중화동         한영(101)
# 16946  서울특별시 중랑구 중화동     현대휴앤미(102동)
#
# [16947 rows x 2 columns]

# %%
display(apt_price[ "시군구":"단지명" ])
# 안돼~ 오류남 슬라이싱 안됨
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [96], in <cell line: 1>()
# ----> 1 display(apt_price["시군구":"단지명"])
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:3477, in DataFrame.__getitem__(self, key)
#    3474         return self._get_item_cache(key)
#    3476 # Do we have a slicer (on rows)?
# -> 3477 indexer = convert_to_index_sliceable(self, key)
#    3478 if indexer is not None:
#    3479     if isinstance(indexer, np.ndarray):
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexing.py:2324, in convert_to_index_sliceable(obj, key)
#    2322 idx = obj.index
#    2323 if isinstance(key, slice):
# -> 2324     return idx._convert_slice_indexer(key, kind="getitem")
#    2326 elif isinstance(key, str):
#    2327
#    2328     # we are an actual column
#    2329     if key in obj.columns:
#
# ...

# %%
display(apt_price[ [ "시군구" , "단지명" ] ])
#팬시인덱싱 됨
# Out:
#                  시군구             단지명
# 0      서울특별시 강남구 개포동  개포6차우성아파트1동~8동
# 1      서울특별시 강남구 개포동  개포6차우성아파트1동~8동
# 2      서울특별시 강남구 개포동  개포6차우성아파트1동~8동
# 3      서울특별시 강남구 개포동  개포6차우성아파트1동~8동
# 4      서울특별시 강남구 개포동  개포6차우성아파트1동~8동
# ...              ...             ...
# 16942  서울특별시 중랑구 중화동  한신아파트(103~109)
# 16943  서울특별시 중랑구 중화동  한신아파트(103~109)
# 16944  서울특별시 중랑구 중화동         한영(101)
# 16945  서울특별시 중랑구 중화동         한영(101)
# 16946  서울특별시 중랑구 중화동     현대휴앤미(102동)
#
# [16947 rows x 2 columns]

# %%
apt_price.rename(columns={"전용면적(㎡)":"전용면적_m2", "거래금액(만원)":"거래금액_만원"}, inplace=True)
apt_price
# Out:
#                  시군구      번지     본번    부번             단지명  전용면적_m2    계약년월  \
# 0      서울특별시 강남구 개포동   658-1  658.0   1.0  개포6차우성아파트1동~8동    79.97  202109
# 1      서울특별시 강남구 개포동   658-1  658.0   1.0  개포6차우성아파트1동~8동    79.97  202112
# 2      서울특별시 강남구 개포동   658-1  658.0   1.0  개포6차우성아파트1동~8동    79.97  202204
# 3      서울특별시 강남구 개포동   658-1  658.0   1.0  개포6차우성아파트1동~8동    79.97  202204
# 4      서울특별시 강남구 개포동   658-1  658.0   1.0  개포6차우성아파트1동~8동    79.97  202205
# ...              ...     ...    ...   ...             ...      ...     ...
# 16942  서울특별시 중랑구 중화동     450  450.0   0.0  한신아파트(103~109)    59.76  202207
# 16943  서울특별시 중랑구 중화동     450  450.0   0.0  한신아파트(103~109)    84.03  202207
# 16944  서울특별시 중랑구 중화동  274-51  274.0  51.0         한영(101)    84.69  202111
# 16945  서울특별시 중랑구 중화동  274-51  274.0  51.0         한영(101)    84.69  202204
# 16946  서울특별시 중랑구 중화동    11-7   11.0   7.0     현대휴앤미(102동)    76.43  202204
#
# ...

# %%
apt_price.head()
# Out:
#              시군구     번지     본번   부번             단지명  전용면적_m2    계약년월  계약일  \
# 0  서울특별시 강남구 개포동  658-1  658.0  1.0  개포6차우성아파트1동~8동    79.97  202109    2
# 1  서울특별시 강남구 개포동  658-1  658.0  1.0  개포6차우성아파트1동~8동    79.97  202112    4
# 2  서울특별시 강남구 개포동  658-1  658.0  1.0  개포6차우성아파트1동~8동    79.97  202204   12
# 3  서울특별시 강남구 개포동  658-1  658.0  1.0  개포6차우성아파트1동~8동    79.97  202204   21
# 4  서울특별시 강남구 개포동  658-1  658.0  1.0  개포6차우성아파트1동~8동    79.97  202205   27
#
#    거래금액_만원  층    건축년도    도로명  해제사유발생일  거래유형  중개사소재지
# 0   220000  2  1987.0  언주로 3      NaN     -       -
# 1   215000  3  1987.0  언주로 3      NaN  중개거래  서울 강남구
# 2   220000  4  1987.0  언주로 3      NaN  중개거래  서울 강남구
# 3   220000  2  1987.0  언주로 3      NaN  중개거래  서울 강남구
# 4   216000  2  1987.0  언주로 3      NaN  중개거래  서울 강남구

# %%
apt_price["층"].unique()
# Out:
# array([ 2,  3,  4,  7,  8,  9,  5, 15, 13, 17,  6, 10, 11,  1, 26, 19, 29,
#        16, 23, 28, 12, 22, 32, 31, 14, 24, 20, 25, 21, 18, 35, 30, 38, 46,
#        27, 34, 60, 64, 39, 56, 45, 36, 47, 42, 40, 62, 52, 33, 63, 44, -1,
#        58, 43, 37, 41], dtype=int64)

# %%
apt_price["층"].nunique() #55가지 종류의 층이 사용됐다
# Out:
# 55

# %%
apt_price["층"].value_counts()
# Out:
#  5     1293
#  4     1223
#  6     1201
#  3     1153
#  7     1083
#  8     1041
#  2     1019
#  9      992
#  11     952
#  12     878
#  10     874
#  13     790
#  1      774
#  14     686
#  15     609
#  16     399
#  17     370
#  18     293
#  19     242
#  20     225
#  21     150
#  22     138
#  23      98
#  24      92
#  25      54
#  26      48
#  27      45
#  28      33
#  29      29
#  30      22
#  32      18
#  31      15
#  34      14
#  33      14
#  35      11
# -1       10
#  39      10
#  36      10
#  38       6
#  42       6
#  45       5
#  40       4
#  41       3
#  46       2
#  43       2
#  37       2
#  56       1
#  47       1
#  64       1
#  62       1
#  52       1
#  60       1
#  63       1
#  44       1
#  58       1
# Name: 층, dtype: int64

# %%
# 거래된 64층 아파트 정보 행 추출
apt_price[ apt_price['층'] == 64 ]
# Out:
#                시군구   번지     본번   부번     단지명  전용면적_m2    계약년월  계약일  거래금액_만원  \
# 440  서울특별시 강남구 도곡동  467  467.0  0.0  타워팰리스1   222.48  202109   30   482500
#
#       층    건축년도        도로명  해제사유발생일 거래유형 중개사소재지
# 440  64  2002.0  언주로30길 56      NaN    -      -

# %%
apt_price[ apt_price['층'] > 50 ]
# Out:
#                 시군구      번지     본번    부번     단지명  전용면적_m2    계약년월  계약일  \
# 439   서울특별시 강남구 도곡동     467  467.0   0.0  타워팰리스1  137.240  202109    2
# 440   서울특별시 강남구 도곡동     467  467.0   0.0  타워팰리스1  222.480  202109   30
# 447   서울특별시 강남구 도곡동     467  467.0   0.0  타워팰리스1  301.470  202205   12
# 471   서울특별시 강남구 도곡동  467-29  467.0  29.0  타워팰리스3  185.622  202111   23
# 474   서울특별시 강남구 도곡동  467-29  467.0  29.0  타워팰리스3  124.641  202202   10
# 476   서울특별시 강남구 도곡동  467-29  467.0  29.0  타워팰리스3  244.224  202203   30
# 3848  서울특별시 광진구 자양동   227-7  227.0   7.0  더샵스타시티  127.950  202204   22
#
#       거래금액_만원   층    건축년도        도로명  해제사유발생일  거래유형   중개사소재지
# 439    368000  60  2002.0  언주로30길 56      NaN     -        -
# 440    482500  64  2002.0  언주로30길 56      NaN     -        -
# 447    870000  56  2002.0  언주로30길 56      NaN  중개거래   서울 강남구
# 471    423000  62  2004.0  언주로30길 26      NaN  중개거래   서울 강남구
# 474    300000  52  2004.0  언주로30길 26      NaN  중개거래   서울 강남구
# ...

# %%
sum(apt_price["건축년도"].isna())
# Out:
# 2

# %%
# 건축년도가 결측치인 거래행 추출
apt_price[apt_price["건축년도"].isna()]
# Out:
#                  시군구  번지    본번   부번        단지명  전용면적_m2    계약년월  계약일  거래금액_만원  \
# 15276  서울특별시 은평구 수색동  30  30.0  0.0  DMCSKVIEW    84.99  202201   28   140000
# 15277  서울특별시 은평구 수색동  30  30.0  0.0  DMCSKVIEW    84.99  202202   10   137000
#
#        층  건축년도      도로명  해제사유발생일  거래유형  중개사소재지
# 15276  7   NaN  수색로 216      NaN  중개거래  서울 은평구
# 15277  6   NaN  수색로 216      NaN  중개거래  서울 은평구

# %%
apt_price[ apt_price["단지명"] == "DMCSKVIEW"]
# Out:
#                  시군구  번지    본번   부번        단지명  전용면적_m2    계약년월  계약일  거래금액_만원  \
# 15276  서울특별시 은평구 수색동  30  30.0  0.0  DMCSKVIEW    84.99  202201   28   140000
# 15277  서울특별시 은평구 수색동  30  30.0  0.0  DMCSKVIEW    84.99  202202   10   137000
#
#        층  건축년도      도로명  해제사유발생일  거래유형  중개사소재지
# 15276  7   NaN  수색로 216      NaN  중개거래  서울 은평구
# 15277  6   NaN  수색로 216      NaN  중개거래  서울 은평구

# %%
apt_price[ apt_price["도로명"] == '수색로 216']
# Out:
#                  시군구  번지    본번   부번        단지명  전용면적_m2    계약년월  계약일  거래금액_만원  \
# 15276  서울특별시 은평구 수색동  30  30.0  0.0  DMCSKVIEW    84.99  202201   28   140000
# 15277  서울특별시 은평구 수색동  30  30.0  0.0  DMCSKVIEW    84.99  202202   10   137000
#
#        층  건축년도      도로명  해제사유발생일  거래유형  중개사소재지
# 15276  7   NaN  수색로 216      NaN  중개거래  서울 은평구
# 15277  6   NaN  수색로 216      NaN  중개거래  서울 은평구

# %%
# 건축년도가 정상인 행 추출
건축년도정상 = apt_price[ apt_price["건축년도"].notna() ]
apt_price["건축년도"] = 건축년도정상['건축년도'].astype("int32")

# %%
apt_price.head()
# Out:
#              시군구     번지     본번   부번             단지명  전용면적(㎡)    계약년월  계약일  \
# 0  서울특별시 강남구 개포동  658-1  658.0  1.0  개포6차우성아파트1동~8동    79.97  202109    2
# 1  서울특별시 강남구 개포동  658-1  658.0  1.0  개포6차우성아파트1동~8동    79.97  202112    4
# 2  서울특별시 강남구 개포동  658-1  658.0  1.0  개포6차우성아파트1동~8동    79.97  202204   12
# 3  서울특별시 강남구 개포동  658-1  658.0  1.0  개포6차우성아파트1동~8동    79.97  202204   21
# 4  서울특별시 강남구 개포동  658-1  658.0  1.0  개포6차우성아파트1동~8동    79.97  202205   27
#
#    거래금액(만원)  층    건축년도    도로명  해제사유발생일  거래유형  중개사소재지
# 0    220000  2  1987.0  언주로 3      NaN     -       -
# 1    215000  3  1987.0  언주로 3      NaN  중개거래  서울 강남구
# 2    220000  4  1987.0  언주로 3      NaN  중개거래  서울 강남구
# 3    220000  2  1987.0  언주로 3      NaN  중개거래  서울 강남구
# 4    216000  2  1987.0  언주로 3      NaN  중개거래  서울 강남구

# %%
 apt_price.sort_index().head(3)
# sort_index()는 오름차순이 기본
# Out:
#              시군구     번지     본번   부번             단지명  전용면적(㎡)    계약년월  계약일  \
# 0  서울특별시 강남구 개포동  658-1  658.0  1.0  개포6차우성아파트1동~8동    79.97  202109    2
# 1  서울특별시 강남구 개포동  658-1  658.0  1.0  개포6차우성아파트1동~8동    79.97  202112    4
# 2  서울특별시 강남구 개포동  658-1  658.0  1.0  개포6차우성아파트1동~8동    79.97  202204   12
#
#    거래금액(만원)  층    건축년도    도로명  해제사유발생일  거래유형  중개사소재지
# 0    220000  2  1987.0  언주로 3      NaN     -       -
# 1    215000  3  1987.0  언주로 3      NaN  중개거래  서울 강남구
# 2    220000  4  1987.0  언주로 3      NaN  중개거래  서울 강남구

# %%
apt_price.sort_index(ascending=False).head(3) #ascending=false 주면 내림차순
# Out:
#                  시군구      번지     본번    부번          단지명  전용면적(㎡)    계약년월  계약일  \
# 16946  서울특별시 중랑구 중화동    11-7   11.0   7.0  현대휴앤미(102동)    76.43  202204   23
# 16945  서울특별시 중랑구 중화동  274-51  274.0  51.0      한영(101)    84.69  202204    9
# 16944  서울특별시 중랑구 중화동  274-51  274.0  51.0      한영(101)    84.69  202111    4
#
#        거래금액(만원)  층    건축년도          도로명  해제사유발생일  거래유형          중개사소재지
# 16946     53000  6  2007.0  봉화산로27가길 19      NaN  중개거래          서울 중랑구
# 16945     49900  7  2003.0   동일로144길 74      NaN  중개거래          서울 중랑구
# 16944     50000  2  2003.0   동일로144길 74      NaN  중개거래  서울 송파구, 서울 중랑구

# %%
apt_price.sort_values(by=["층","거래금액_만원"], ascending=[True,False])
# Out:
#                  시군구      번지      본번    부번                단지명  전용면적_m2  \
# 15714  서울특별시 은평구 진관동      84    84.0   0.0  은평뉴타운우물골(두산위브7단지)  134.750
# 14709  서울특별시 용산구 이촌동   193-3   193.0   3.0                 강변   66.080
# 16924  서울특별시 중랑구 중화동  331-64   331.0  64.0              연합파크빌   80.010
# 3029   서울특별시 관악구 남현동  1081-4  1081.0   4.0                 우평   99.290
# 3030   서울특별시 관악구 남현동  1081-4  1081.0   4.0                 우평   99.290
# ...              ...     ...     ...   ...                ...      ...
# 3848   서울특별시 광진구 자양동   227-7   227.0   7.0             더샵스타시티  127.950
# 439    서울특별시 강남구 도곡동     467   467.0   0.0             타워팰리스1  137.240
# 471    서울특별시 강남구 도곡동  467-29   467.0  29.0             타워팰리스3  185.622
# 476    서울특별시 강남구 도곡동  467-29   467.0  29.0             타워팰리스3  244.224
# 440    서울특별시 강남구 도곡동     467   467.0   0.0             타워팰리스1  222.480
#
#          계약년월  계약일  거래금액_만원   층    건축년도           도로명     해제사유발생일  거래유형  \
# ...
